# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [8]</a>'.</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

df = pd.read_csv('../base_dados/beber_copia2.csv', low_memory=False)

# %% [markdown]
# ## MÉTODO DO COTOVELO PARA SABER QUAL MELHOR VALOR PARA CADA ATRIBUTO

# %% [markdown]
# #### waistline

# %%
data = df[['waistline']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['waistline']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['waistline'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna waistline_grupo
df['waistline_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['waistline'], inplace=True)

# %% [markdown]
# #### weight

# %%
data = df[['weight']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['weight']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['weight'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna weight_grupo
df['weight_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['weight'], inplace=True)

# %% [markdown]
# ### Serum Creatine

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
data = df[['serum_creatinine']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['serum_creatinine']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=4, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['serum_creatinine'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna serum_creatinine_grupo
df['serum_creatinine_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['serum_creatinine'], inplace=True)

# %% [markdown]
# ### tot_chole

# %%
data = df[['tot_chole']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['tot_chole']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['tot_chole'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna tot_chole_grupo
df['tot_chole_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['tot_chole'], inplace=True)

# %% [markdown]
# ### hdl_chole

# %%
data = df[['hdl_chole']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['hdl_chole']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['hdl_chole'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna hdl_chole_grupo
df['hdl_chole_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['hdl_chole'], inplace=True)

# %% [markdown]
# ###  ldl_chole

# %%
data = df[['ldl_chole']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['ldl_chole']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['ldl_chole'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna ldl_chole_grupo
df['ldl_chole_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['ldl_chole'], inplace=True)

# %% [markdown]
# ### triglyceride

# %%
data = df[['triglyceride']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['triglyceride']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['triglyceride'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna triglyceride_grupo
df['triglyceride_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['triglyceride'], inplace=True)

# %% [markdown]
# ### sgot_ast

# %%
data = df[['sgot_ast']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['sgot_ast']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['sgot_ast'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna sgot_ast_grupo
df['sgot_ast_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['sgot_ast'], inplace=True)

# %% [markdown]
# ### gamma_gtp

# %%
data = df[['gamma_gtp']].dropna()  # Remover valores ausentes

sse = []

# Intervalo de clusters de 2 a 20
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    sse.append(kmeans.inertia_)

# Plotar o gráfico do Método do Cotovelo
plt.figure(figsize=(8, 5))
plt.plot(range(2, 21), sse, marker='o')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Soma dos Erros Quadráticos (SSE)')
plt.title('Método do Cotovelo')
plt.xticks(range(2, 21))
plt.grid()
plt.show()

# %%
X = df[['gamma_gtp']]

# Aplicar o KMeans
kmeans = KMeans(n_clusters=6, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# Calcular os centróides reais dos clusters
centroides_reais = df.groupby('cluster')['gamma_gtp'].mean()

# Mapear os valores dos centróides formatados para uma nova coluna gamma_gtp_grupo
df['gamma_gtp_grupo'] = df['cluster'].map(lambda cluster: round(centroides_reais[cluster], 2))

# Remover a coluna cluster, caso não seja necessária
df.drop(columns=['cluster'], inplace=True)
df.drop(columns=['gamma_gtp'], inplace=True)

# %% [markdown]
# ### Mostrar atributos

# %%
print("Valores únicos por atributo:")

df_colunas = df[df.columns]

for coluna in df_colunas.columns:
    # Garantir valores únicos e ordenados corretamente
    valores_unicos = sorted(set(df[coluna].dropna()))  # Usar set() para garantir a unicidade
    # Converter valores numéricos para inteiros ou floats simples
    valores_unicos = [int(valor) if isinstance(valor, (int, np.integer)) else valor for valor in valores_unicos]
    print(f"\nColuna: {coluna}")
    print(f"Valores únicos ({len(valores_unicos)}): {valores_unicos}")
# Out:
# Valores únicos por atributo:
#
# Coluna: sex
# Valores únicos (2): [0, 1]
#
# Coluna: age
# Valores únicos (14): [20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 85]
#
# Coluna: height
# Valores únicos (13): [130, 135, 140, 145, 150, 155, 160, 165, 170, 175, 180, 185, 190]
#
# Coluna: sight_left
# Valores únicos (4): [0, 1, 2, 9]
#
# Coluna: sight_right
# Valores únicos (4): [0, 1, 2, 9]
#
# Coluna: hear_left
# Valores únicos (2): [1, 2]
#
# Coluna: hear_right
# Valores únicos (2): [1, 2]
#
# Coluna: urine_protein
# Valores únicos (6): [1, 2, 3, 4, 5, 6]
#
# Coluna: smk_stat_type_cd
# Valores únicos (3): [1, 2, 3]
#
# Coluna: drk_yn
# Valores únicos (2): [0, 1]
#
# Coluna: sbp_grupo
# Valores únicos (6): [90, 120, 129, 139, 179, 199]
#
# Coluna: dbp_grupo
# Valores únicos (6): [60, 80, 89, 99, 119, 140]
#
# Coluna: blds_grupo
# Valores únicos (3): [100, 125, 150]
#
# Coluna: hemoglobin_grupo
# Valores únicos (3): [13, 17, 21]
#
# Coluna: waistline_grupo
# ...

# %% [markdown]
# ## Salvar Dados

# %%
df.to_csv('../base_dados/beber_copia2.csv', index=False)
