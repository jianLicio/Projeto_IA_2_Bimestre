# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('../base_dados/beber_copia2.csv', low_memory=False)

# %%
scaler = MinMaxScaler()
df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])

df = df.drop_duplicates()
# Out:
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.23076923 0.15384615 0.30769231 ... 0.30769231 0.07692308 0.46153846]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.66666667 0.83333333 0.58333333 ... 0.41666667 0.75       0.5       ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.11111111 0.         0.11111111 ... 0.11111111 0.11111111 0.11111111]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.11111111 0.11111111 0.11111111 ... 0.         0.11111111 0.11111111]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 1. 0. ... 1. 0. 1.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.27522936 0.44954128 0.27522936 ... 0.27522936 0.27522936 0.44954128]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.25   0.3625 0.25   ... 0.25   0.25   0.25  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.  0.5 0.  ... 0.  0.  0. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
# C:\Users\jian_\AppData\Local\Temp\ipykernel_7340\186129472.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.5 0.  0.  ... 0.5 0.  0. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])

# %%
df.to_csv('../base_dados/beber_knn.csv', index=False)
